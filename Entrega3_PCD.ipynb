# %% [markdown]
# # Projeto PCD: Simulação e Análise de Modelos de Difusão de Contaminantes em Água
#
# ## Profs. Álvaro e Denise (Turmas I e N)
#
# **Objetivo**: Criar uma simulação que modele a difusão de contaminantes em um corpo d'água (como um lago ou rio), aplicando conceitos de paralelismo para acelerar o cálculo e observar o comportamento de poluentes ao longo do tempo. O projeto investigará o impacto de OpenMP, CUDA e MPI no tempo de execução e na precisão do modelo.
#
# ## Etapas do Projeto
#
# ### 1. Estudo do Modelo de Difusão
#    - Estudar a Equação de Difusão/Transporte transiente, representada por:
# ![Captura de tela de 2024-10-31 17-06-58.png](data:image/png;base64,...)
#
#    - A equação diferencial pode ser aproximada (discretizada) no tempo e no espaço usando diferenças finitas em uma grade bidimensional, onde a discretização no espaço implica que cada célula da grade atualiza seu valor com base nas células vizinhas em cada iteração. O cálculo da grade atualizada deverá se repetir para que sejam feitas várias interações discretas no tempo.
#
# ### 2. Configuração do Ambiente e Parâmetros da Simulação
#    - Configurar uma grade 2D onde cada célula representa a concentração de contaminantes em uma região do corpo d'água.
#    - Definir o coeficiente de difusão \(D\), as condições de contorno (por exemplo, bordas onde o contaminante não se espalha) e as condições iniciais (como uma área de alta concentração de contaminante).
#    - Definir uma quantidade fixa de interações no tempo como 1000 iterações.
#
# ### 3. Implementação com OpenMP (Simulação Local em CPU)
#    - Usar OpenMP para paralelizar o cálculo de difusão entre os núcleos da CPU. Cada núcleo processa uma parte da grade, aplicando as regras de difusão às células sob sua responsabilidade.
#    -**Entrega 1**: demonstrar o código em OpenMP e apresentar avaliação de desempenho com relação à versão sequencial.
#
# ### 4. Implementação com CUDA (Simulação em GPU)
#    - Implementar a simulação em CUDA, onde cada célula da grade é processada por uma thread independente na GPU, utilizando um esquema de diferenças finitas para calcular o laplaciano de \(C\).
#    - A execução em GPU permite simular uma grade maior e observar o ganho de desempenho com CUDA.
#    -**Entrega 2**: demonstrar o código em CUDA e apresentar avaliação de desempenho com relação às versões anteriores.
#
# ### 5. Distribuição com MPI (Simulação em Larga Escala)
#    - Dividir a grade em sub-regiões e distribuir o processamento entre várias máquinas usando MPI.
#    - Cada máquina processa uma seção do corpo d'água e troca informações nas bordas com as máquinas vizinhas para garantir a continuidade da difusão de contaminantes entre as regiões.
#    -**Entrega 3**: demonstrar o código em MPI hibrido (pode incluir trechos em OpenMP e CUDA) e apresentar avaliação de desempenho com relação às versões anteriores, porém destacando a escalabilidade possível apenas com MPI.
#
# ### 6. Artigo científico e Discussão dos Resultados
#    - Criar gráficos que mostrem a evolução da concentração ao longo do tempo e comparar o tempo de execução entre as implementações.
#    - Discutir as vantagens e limitações de cada abordagem, observando a escalabilidade, precisão e aplicabilidade em simulações ambientais.
#    - Demonstrar visualmente os resultados que comprovem a corretude da simulação.
#    -**Entrega Final**: entregar o resultado final no formato de artigo científico (modelo a ser disponibilizado).
#
#
# ## Ponto de Partida para a Implementação da Equação
#
# Para aproximar a Equação de Difusão, podemos usar a seguinte fórmula de diferenças finitas central:
# ![Captura de tela de 2024-10-31 17-00-24.png](data:image/png;base64,...)
#
# Abaixo está um trecho de código em C para uma implementação sequencial simples, o qual calcula a difusão do contaminante em uma grade de 2000x2000 ao longo de 500 ciclos. A concentração inicial está configurada no centro da grade, e o coeficiente de difusão \(D\) pode ser ajustado conforme necessário.

# %%
# !apt-get update
# !apt-get install -y mpich
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,315 kB]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,677 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,911 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,526 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,656 kB]
# Fetched 17.5 MB in 4s (4,496 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   hwloc-nox libmpich-dev libmpich12 libslurm37
# Suggested packages:
#   mpich-doc
# The following NEW packages will be installed:
#   hwloc-nox libmpich-dev libmpich12 libslurm37 mpich
# 0 upgraded, 5 newly installed, 0 to remove and 22 not upgraded.
# Need to get 14.2 MB of archives.
# After this operation, 102 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libslurm37 amd64 21.08.5-2ubuntu1 [542 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 hwloc-nox amd64 2.7.0-2ubuntu1 [205 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmpich12 amd64 4.0-3 [5,866 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 mpich amd64 4.0-3 [197 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmpich-dev amd64 4.0-3 [7,375 kB]
# Fetched 14.2 MB in 2s (5,746 kB/s)
# Selecting previously unselected package libslurm37.
# (Reading database ... 124926 files and directories currently installed.)
# Preparing to unpack .../libslurm37_21.08.5-2ubuntu1_amd64.deb ...
# Unpacking libslurm37 (21.08.5-2ubuntu1) ...
# Selecting previously unselected package hwloc-nox.
# Preparing to unpack .../hwloc-nox_2.7.0-2ubuntu1_amd64.deb ...
# Unpacking hwloc-nox (2.7.0-2ubuntu1) ...
# Selecting previously unselected package libmpich12:amd64.
# Preparing to unpack .../libmpich12_4.0-3_amd64.deb ...
# Unpacking libmpich12:amd64 (4.0-3) ...
# Selecting previously unselected package mpich.
# Preparing to unpack .../archives/mpich_4.0-3_amd64.deb ...
# Unpacking mpich (4.0-3) ...
# Selecting previously unselected package libmpich-dev:amd64.
# Preparing to unpack .../libmpich-dev_4.0-3_amd64.deb ...
# Unpacking libmpich-dev:amd64 (4.0-3) ...
# Setting up libslurm37 (21.08.5-2ubuntu1) ...
# Setting up hwloc-nox (2.7.0-2ubuntu1) ...
# Setting up libmpich12:amd64 (4.0-3) ...
# Setting up mpich (4.0-3) ...
# Setting up libmpich-dev:amd64 (4.0-3) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link

# %%
# !apt-get install -y cuda
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cpp-12 cuda-12-8 cuda-cccl-12-8 cuda-command-line-tools-12-8 cuda-compiler-12-8 cuda-crt-12-8
#   cuda-cudart-12-8 cuda-cudart-dev-12-8 cuda-cuobjdump-12-8 cuda-cupti-12-8 cuda-cupti-dev-12-8
#   cuda-cuxxfilt-12-8 cuda-demo-suite-12-8 cuda-documentation-12-8 cuda-driver-dev-12-8
#   cuda-gdb-12-8 cuda-libraries-12-8 cuda-libraries-dev-12-8 cuda-nsight-12-8
#   cuda-nsight-compute-12-8 cuda-nsight-systems-12-8 cuda-nvcc-12-8 cuda-nvdisasm-12-8
#   cuda-nvml-dev-12-8 cuda-nvprof-12-8 cuda-nvprune-12-8 cuda-nvrtc-12-8 cuda-nvrtc-dev-12-8
#   cuda-nvtx-12-8 cuda-nvvm-12-8 cuda-nvvp-12-8 cuda-opencl-12-8 cuda-opencl-dev-12-8
#   cuda-profiler-api-12-8 cuda-runtime-12-8 cuda-sanitizer-12-8 cuda-toolkit-12-8
#   cuda-toolkit-12-8-config-common cuda-tools-12-8 cuda-visual-tools-12-8 dctrl-tools default-jre
#   default-jre-headless dkms fakeroot fonts-dejavu-core fonts-dejavu-extra gcc-12 gds-tools-12-8
#   keyboard-configuration libasan8 libatk-wrapper-java libatk-wrapper-java-jni libcublas-12-8
#   libcublas-dev-12-8 libcufft-12-8 libcufft-dev-12-8 libcufile-12-8 libcufile-dev-12-8
#   libcurand-12-8 libcurand-dev-12-8 libcusolver-12-8 libcusolver-dev-12-8 libcusparse-12-8
#   libcusparse-dev-12-8 libfakeroot libfontenc1 libgail-common libgail18 libgcc-12-dev libgtk2.0-0
#   libgtk2.0-bin libgtk2.0-common libgudev-1.0-0 libjansson4 liblocale-gettext-perl libnpp-12-8
#   libnpp-dev-12-8 libnvfatbin-12-8 libnvfatbin-dev-12-8 libnvidia-cfg1-570 libnvidia-common-570
#   libnvidia-compute-570 libnvidia-decode-570 libnvidia-encode-570 libnvidia-extra-570
#   libnvidia-fbc1-570 libnvidia-gl-570 libnvjitlink-12-8 libnvjitlink-dev-12-8 libnvjpeg-12-8
#   libnvjpeg-dev-12-8 librsvg2-common libtsan2 libxcb-cursor0 libxcb-icccm4 libxcb-image0
#   libxcb-keysyms1 libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxcvt0 libxfont2 libxkbcommon-x11-0 libxkbfile1 libxtst6 libxxf86dga1 nsight-compute-2025.1.0
#   nsight-systems-2024.6.2 nvidia-compute-utils-570 nvidia-dkms-570-open nvidia-driver-570-open
#   nvidia-firmware-570-570.86.15 nvidia-kernel-common-570 nvidia-kernel-source-570-open
#   nvidia-modprobe nvidia-open nvidia-settings nvidia-utils-570 openjdk-11-jre python3-xkit
#   screen-resolution-extra switcheroo-control systemd-hwe-hwdb udev x11-utils x11-xkb-utils xcvt
#   xfonts-base xfonts-encodings xfonts-utils xserver-common xserver-xorg-core
#   xserver-xorg-video-nvidia-570
# Suggested packages:
#   gcc-12-locales cpp-12-doc debtags menu gcc-12-multilib gcc-12-doc gvfs nvidia-driver-570
#   mesa-utils xfs | xserver xfonts-100dpi | xfonts-75dpi xfonts-scalable
# Recommended packages:
#   libnvidia-compute-570:i386 libnvidia-decode-570:i386 libnvidia-encode-570:i386
#   libnvidia-fbc1-570:i386 libnvidia-gl-570:i386
# The following NEW packages will be installed:
#   cpp-12 cuda cuda-12-8 cuda-cccl-12-8 cuda-command-line-tools-12-8 cuda-compiler-12-8
#   cuda-crt-12-8 cuda-cudart-12-8 cuda-cudart-dev-12-8 cuda-cuobjdump-12-8 cuda-cupti-12-8
#   cuda-cupti-dev-12-8 cuda-cuxxfilt-12-8 cuda-demo-suite-12-8 cuda-documentation-12-8
#   cuda-driver-dev-12-8 cuda-gdb-12-8 cuda-libraries-12-8 cuda-libraries-dev-12-8 cuda-nsight-12-8
#   cuda-nsight-compute-12-8 cuda-nsight-systems-12-8 cuda-nvcc-12-8 cuda-nvdisasm-12-8
#   cuda-nvml-dev-12-8 cuda-nvprof-12-8 cuda-nvprune-12-8 cuda-nvrtc-12-8 cuda-nvrtc-dev-12-8
#   cuda-nvtx-12-8 cuda-nvvm-12-8 cuda-nvvp-12-8 cuda-opencl-12-8 cuda-opencl-dev-12-8
#   cuda-profiler-api-12-8 cuda-runtime-12-8 cuda-sanitizer-12-8 cuda-toolkit-12-8
#   cuda-toolkit-12-8-config-common cuda-tools-12-8 cuda-visual-tools-12-8 dctrl-tools default-jre
#   default-jre-headless dkms fakeroot fonts-dejavu-core fonts-dejavu-extra gcc-12 gds-tools-12-8
#   keyboard-configuration libasan8 libatk-wrapper-java libatk-wrapper-java-jni libcublas-12-8
#   libcublas-dev-12-8 libcufft-12-8 libcufft-dev-12-8 libcufile-12-8 libcufile-dev-12-8
#   libcurand-12-8 libcurand-dev-12-8 libcusolver-12-8 libcusolver-dev-12-8 libcusparse-12-8
#   libcusparse-dev-12-8 libfakeroot libfontenc1 libgail-common libgail18 libgcc-12-dev libgtk2.0-0
#   libgtk2.0-bin libgtk2.0-common libgudev-1.0-0 libjansson4 liblocale-gettext-perl libnpp-12-8
#   libnpp-dev-12-8 libnvfatbin-12-8 libnvfatbin-dev-12-8 libnvidia-cfg1-570 libnvidia-common-570
#   libnvidia-compute-570 libnvidia-decode-570 libnvidia-encode-570 libnvidia-extra-570
#   libnvidia-fbc1-570 libnvidia-gl-570 libnvjitlink-12-8 libnvjitlink-dev-12-8 libnvjpeg-12-8
#   libnvjpeg-dev-12-8 librsvg2-common libtsan2 libxcb-cursor0 libxcb-icccm4 libxcb-image0
#   libxcb-keysyms1 libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxcvt0 libxfont2 libxkbcommon-x11-0 libxkbfile1 libxtst6 libxxf86dga1 nsight-compute-2025.1.0
#   nsight-systems-2024.6.2 nvidia-compute-utils-570 nvidia-dkms-570-open nvidia-driver-570-open
#   nvidia-firmware-570-570.86.15 nvidia-kernel-common-570 nvidia-kernel-source-570-open
#   nvidia-modprobe nvidia-open nvidia-settings nvidia-utils-570 openjdk-11-jre python3-xkit
#   screen-resolution-extra switcheroo-control systemd-hwe-hwdb udev x11-utils x11-xkb-utils xcvt
#   xfonts-base xfonts-encodings xfonts-utils xserver-common xserver-xorg-core
#   xserver-xorg-video-nvidia-570
# 0 upgraded, 137 newly installed, 0 to remove and 22 not upgraded.
# Need to get 3,984 MB of archives.
# After this operation, 9,511 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblocale-gettext-perl amd64 1.07-4build3 [17.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 keyboard-configuration all 1.205ubuntu3 [206 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 cpp-12 amd64 12.3.0-1ubuntu1~22.04 [10.8 MB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-12-8-config-common 12.8.57-1 [16.5 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libasan8 amd64 12.3.0-1ubuntu1~22.04 [2,442 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtsan2 amd64 12.3.0-1ubuntu1~22.04 [2,477 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgcc-12-dev amd64 12.3.0-1ubuntu1~22.04 [2,618 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gcc-12 amd64 12.3.0-1ubuntu1~22.04 [21.7 MB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 dctrl-tools amd64 2.24-3build2 [66.9 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 dkms all 2.8.7-2ubuntu2.2 [70.1 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.12 [1,557 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjansson4 amd64 2.13.1-1.1build3 [32.4 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxcb-cursor0 amd64 0.1.1-4ubuntu1 [10.5 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.26+4-1ubuntu1~22.04 [214 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.12 [28.7 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcvt0 amd64 0.1.1-3 [5,494 B]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-xorg-core amd64 2:21.1.4-2ubuntu1.7~22.04.12 [1,477 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfakeroot amd64 1.28-1ubuntu1 [31.5 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 fakeroot amd64 1.28-1ubuntu1 [60.4 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:39 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cudart-12-8 12.8.57-1 [170 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-common all 2.24.33-2ubuntu2.1 [125 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-0 amd64 2.24.33-2ubuntu2.1 [2,038 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail18 amd64 2.24.33-2ubuntu2.1 [15.9 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail-common amd64 2.24.33-2ubuntu2.1 [132 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-bin amd64 2.24.33-2ubuntu2.1 [7,936 B]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-xkit all 0.5.0ubuntu5 [18.5 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/main amd64 screen-resolution-extra all 0.18.2 [4,396 B]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/main amd64 switcheroo-control amd64 2.4-3build2 [16.5 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 systemd-hwe-hwdb all 249.11.5 [3,228 B]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/main amd64 xcvt amd64 0.1.1-3 [7,140 B]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:58 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvrtc-12-8 12.8.61-1 [62.3 MB]
# Get:59 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-opencl-12-8 12.8.55-1 [23.9 kB]
# Get:60 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcublas-12-8 12.8.3.14-1 [474 MB]
# Get:61 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufft-12-8 11.3.3.41-1 [151 MB]
# Get:62 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufile-12-8 1.13.0.11-1 [885 kB]
# Get:63 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcurand-12-8 10.3.9.55-1 [44.7 MB]
# Get:64 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusolver-12-8 11.7.2.55-1 [160 MB]
# Get:65 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusparse-12-8 12.5.7.53-1 [166 MB]
# Get:66 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnpp-12-8 12.3.3.65-1 [131 MB]
# Get:67 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjitlink-12-8 12.8.61-1 [28.3 MB]
# Get:68 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvfatbin-12-8 12.8.55-1 [743 kB]
# Get:69 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjpeg-12-8 12.3.5.57-1 [2,895 kB]
# Get:70 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-libraries-12-8 12.8.0-1 [2,610 B]
# Get:71 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-decode-570 570.86.15-0ubuntu1 [2,434 kB]
# Get:72 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-compute-570 570.86.15-0ubuntu1 [44.0 MB]
# Get:73 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-runtime-12-8 12.8.0-1 [2,510 B]
# Get:74 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cuobjdump-12-8 12.8.55-1 [210 kB]
# Get:75 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cuxxfilt-12-8 12.8.55-1 [191 kB]
# Get:76 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cccl-12-8 12.8.55-1 [966 kB]
# Get:77 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-driver-dev-12-8 12.8.57-1 [29.1 kB]
# Get:78 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cudart-dev-12-8 12.8.57-1 [1,246 kB]
# Get:79 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvvm-12-8 12.8.61-1 [43.8 MB]
# Get:80 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-crt-12-8 12.8.61-1 [81.1 kB]
# Get:81 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvcc-12-8 12.8.61-1 [36.1 MB]
# Get:82 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvprune-12-8 12.8.55-1 [60.6 kB]
# Get:83 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-compiler-12-8 12.8.0-1 [2,506 B]
# Get:84 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-profiler-api-12-8 12.8.55-1 [18.6 kB]
# Get:85 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvrtc-dev-12-8 12.8.61-1 [53.1 MB]
# Get:86 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-opencl-dev-12-8 12.8.55-1 [89.5 kB]
# Get:87 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcublas-dev-12-8 12.8.3.14-1 [498 MB]
# Get:88 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufft-dev-12-8 11.3.3.41-1 [302 MB]
# Get:89 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcufile-dev-12-8 1.13.0.11-1 [2,677 kB]
# Get:90 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcurand-dev-12-8 10.3.9.55-1 [44.8 MB]
# Get:91 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusolver-dev-12-8 11.7.2.55-1 [106 MB]
# Get:92 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcusparse-dev-12-8 12.5.7.53-1 [171 MB]
# Get:93 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnpp-dev-12-8 12.3.3.65-1 [130 MB]
# Get:94 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjitlink-dev-12-8 12.8.61-1 [26.1 MB]
# Get:95 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvfatbin-dev-12-8 12.8.55-1 [619 kB]
# Get:96 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvjpeg-dev-12-8 12.3.5.57-1 [2,598 kB]
# Get:97 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-libraries-dev-12-8 12.8.0-1 [2,650 B]
# Get:98 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cupti-12-8 12.8.57-1 [11.4 MB]
# Get:99 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-cupti-dev-12-8 12.8.57-1 [4,075 kB]
# Get:100 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvdisasm-12-8 12.8.55-1 [5,086 kB]
# Get:101 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-gdb-12-8 12.8.55-1 [25.1 MB]
# Get:102 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvprof-12-8 12.8.57-1 [2,398 kB]
# Get:103 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvtx-12-8 12.8.55-1 [52.0 kB]
# Get:104 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-sanitizer-12-8 12.8.55-1 [10.3 MB]
# Get:105 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-command-line-tools-12-8 12.8.0-1 [2,542 B]
# Get:106 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-compute-2025.1.0 2025.1.0.14-1 [295 MB]
# Get:107 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-compute-12-8 12.8.0-1 [4,060 B]
# Get:108 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-systems-2024.6.2 2024.6.2.225-246235244400v0 [374 MB]
# Get:109 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-systems-12-8 12.8.0-1 [3,352 B]
# Get:110 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nsight-12-8 12.8.55-1 [119 MB]
# Get:111 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvml-dev-12-8 12.8.55-1 [127 kB]
# Get:112 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-nvvp-12-8 12.8.57-1 [115 MB]
# Get:113 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-visual-tools-12-8 12.8.0-1 [2,946 B]
# Get:114 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  gds-tools-12-8 1.13.0.11-1 [39.0 MB]
# Get:115 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-tools-12-8 12.8.0-1 [2,466 B]
# Get:116 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-documentation-12-8 12.8.55-1 [49.9 kB]
# Get:117 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-toolkit-12-8 12.8.0-1 [3,360 B]
# Get:118 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-demo-suite-12-8 12.8.55-1 [4,003 kB]
# Get:119 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda-12-8 12.8.0-1 [2,522 B]
# Get:120 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-common-570 570.86.15-0ubuntu1 [15.9 kB]
# Get:121 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-gl-570 570.86.15-0ubuntu1 [162 MB]
# Get:122 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-kernel-source-570-open 570.86.15-0ubuntu1 [6,469 kB]
# Get:123 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-firmware-570-570.86.15 570.86.15-0ubuntu1 [64.5 MB]
# Get:124 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-modprobe 570.86.15-0ubuntu1 [14.9 kB]
# Get:125 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-kernel-common-570 570.86.15-0ubuntu1 [98.6 kB]
# Get:126 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-dkms-570-open 570.86.15-0ubuntu1 [14.9 kB]
# Get:127 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-extra-570 570.86.15-0ubuntu1 [72.7 kB]
# Get:128 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-compute-utils-570 570.86.15-0ubuntu1 [108 kB]
# Get:129 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-encode-570 570.86.15-0ubuntu1 [105 kB]
# Get:130 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-utils-570 570.86.15-0ubuntu1 [520 kB]
# Get:131 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-cfg1-570 570.86.15-0ubuntu1 [145 kB]
# Get:132 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  xserver-xorg-video-nvidia-570 570.86.15-0ubuntu1 [1,694 kB]
# Get:133 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-fbc1-570 570.86.15-0ubuntu1 [98.3 kB]
# Get:134 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-driver-570-open 570.86.15-0ubuntu1 [12.2 kB]
# Get:135 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-open 570.86.15-0ubuntu1 [2,546 B]
# Get:136 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  cuda 12.8.0-1 [2,490 B]
# Get:137 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nvidia-settings 570.86.15-0ubuntu1 [959 kB]
# Fetched 3,984 MB in 2min 54s (23.0 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package liblocale-gettext-perl.
# (Reading database ... 125052 files and directories currently installed.)
# Preparing to unpack .../000-liblocale-gettext-perl_1.07-4build3_amd64.deb ...
# Unpacking liblocale-gettext-perl (1.07-4build3) ...
# Selecting previously unselected package keyboard-configuration.
# Preparing to unpack .../001-keyboard-configuration_1.205ubuntu3_all.deb ...
# Unpacking keyboard-configuration (1.205ubuntu3) ...
# Selecting previously unselected package cpp-12.
# Preparing to unpack .../002-cpp-12_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking cpp-12 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libasan8:amd64.
# Preparing to unpack .../003-libasan8_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking libasan8:amd64 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libtsan2:amd64.
# Preparing to unpack .../004-libtsan2_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking libtsan2:amd64 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libgcc-12-dev:amd64.
# Preparing to unpack .../005-libgcc-12-dev_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking libgcc-12-dev:amd64 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package gcc-12.
# Preparing to unpack .../006-gcc-12_12.3.0-1ubuntu1~22.04_amd64.deb ...
# Unpacking gcc-12 (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package dctrl-tools.
# Preparing to unpack .../007-dctrl-tools_2.24-3build2_amd64.deb ...
# Unpacking dctrl-tools (2.24-3build2) ...
# Selecting previously unselected package dkms.
# Preparing to unpack .../008-dkms_2.8.7-2ubuntu2.2_all.deb ...
# Unpacking dkms (2.8.7-2ubuntu2.2) ...
# Selecting previously unselected package udev.
# Preparing to unpack .../009-udev_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking udev (249.11-0ubuntu3.12) ...
# Selecting previously unselected package libjansson4:amd64.
# Preparing to unpack .../010-libjansson4_2.13.1-1.1build3_amd64.deb ...
# Unpacking libjansson4:amd64 (2.13.1-1.1build3) ...
# Selecting previously unselected package cuda-toolkit-12-8-config-common.
# Preparing to unpack .../011-cuda-toolkit-12-8-config-common_12.8.57-1_all.deb ...
# Unpacking cuda-toolkit-12-8-config-common (12.8.57-1) ...
# Selecting previously unselected package cuda-cudart-12-8.
# Preparing to unpack .../012-cuda-cudart-12-8_12.8.57-1_amd64.deb ...
# Unpacking cuda-cudart-12-8 (12.8.57-1) ...
# Selecting previously unselected package cuda-nvrtc-12-8.
# Preparing to unpack .../013-cuda-nvrtc-12-8_12.8.61-1_amd64.deb ...
# Unpacking cuda-nvrtc-12-8 (12.8.61-1) ...
# Selecting previously unselected package cuda-opencl-12-8.
# Preparing to unpack .../014-cuda-opencl-12-8_12.8.55-1_amd64.deb ...
# Unpacking cuda-opencl-12-8 (12.8.55-1) ...
# Selecting previously unselected package libcublas-12-8.
# Preparing to unpack .../015-libcublas-12-8_12.8.3.14-1_amd64.deb ...
# Unpacking libcublas-12-8 (12.8.3.14-1) ...
# Selecting previously unselected package libcufft-12-8.
# Preparing to unpack .../016-libcufft-12-8_11.3.3.41-1_amd64.deb ...
# Unpacking libcufft-12-8 (11.3.3.41-1) ...
# Selecting previously unselected package libcufile-12-8.
# Preparing to unpack .../017-libcufile-12-8_1.13.0.11-1_amd64.deb ...
# Unpacking libcufile-12-8 (1.13.0.11-1) ...
# Selecting previously unselected package libcurand-12-8.
# Preparing to unpack .../018-libcurand-12-8_10.3.9.55-1_amd64.deb ...
# Unpacking libcurand-12-8 (10.3.9.55-1) ...
# Selecting previously unselected package libcusolver-12-8.
# Preparing to unpack .../019-libcusolver-12-8_11.7.2.55-1_amd64.deb ...
# Unpacking libcusolver-12-8 (11.7.2.55-1) ...
# Selecting previously unselected package libcusparse-12-8.
# Preparing to unpack .../020-libcusparse-12-8_12.5.7.53-1_amd64.deb ...
# Unpacking libcusparse-12-8 (12.5.7.53-1) ...
# Selecting previously unselected package libnpp-12-8.
# Preparing to unpack .../021-libnpp-12-8_12.3.3.65-1_amd64.deb ...
# Unpacking libnpp-12-8 (12.3.3.65-1) ...
# Selecting previously unselected package libnvjitlink-12-8.
# Preparing to unpack .../022-libnvjitlink-12-8_12.8.61-1_amd64.deb ...
# Unpacking libnvjitlink-12-8 (12.8.61-1) ...
# Selecting previously unselected package libnvfatbin-12-8.
# Preparing to unpack .../023-libnvfatbin-12-8_12.8.55-1_amd64.deb ...
# Unpacking libnvfatbin-12-8 (12.8.55-1) ...
# Selecting previously unselected package libnvjpeg-12-8.
# Preparing to unpack .../024-libnvjpeg-12-8_12.3.5.57-1_amd64.deb ...
# Unpacking libnvjpeg-12-8 (12.3.5.57-1) ...
# Selecting previously unselected package cuda-libraries-12-8.
# Preparing to unpack .../025-cuda-libraries-12-8_12.8.0-1_amd64.deb ...
# Unpacking cuda-libraries-12-8 (12.8.0-1) ...
# Selecting previously unselected package libnvidia-decode-570:amd64.
# Preparing to unpack .../026-libnvidia-decode-570_570.86.15-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-decode-570:amd64 (570.86.15-0ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-570:amd64.
# Preparing to unpack .../027-libnvidia-compute-570_570.86.15-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-compute-570:amd64 (570.86.15-0ubuntu1) ...
# Selecting previously unselected package cuda-runtime-12-8.
# Preparing to unpack .../028-cuda-runtime-12-8_12.8.0-1_amd64.deb ...
# Unpacking cuda-runtime-12-8 (12.8.0-1) ...
# Selecting previously unselected package cuda-cuobjdump-12-8.
# Preparing to unpack .../029-cuda-cuobjdump-12-8_12.8.55-1_amd64.deb ...
# Unpacking cuda-cuobjdump-12-8 (12.8.55-1) ...
# Selecting previously unselected package cuda-cuxxfilt-12-8.
# Preparing to unpack .../030-cuda-cuxxfilt-12-8_12.8.55-1_amd64.deb ...
# Unpacking cuda-cuxxfilt-12-8 (12.8.55-1) ...
# Selecting previously unselected package cuda-cccl-12-8.
# Preparing to unpack .../031-cuda-cccl-12-8_12.8.55-1_amd64.deb ...
# Unpacking cuda-cccl-12-8 (12.8.55-1) ...
# Selecting previously unselected package cuda-driver-dev-12-8.
# Preparing to unpack .../032-cuda-driver-dev-12-8_12.8.57-1_amd64.deb ...
# Unpacking cuda-driver-dev-12-8 (12.8.57-1) ...
# Selecting previously unselected package cuda-cudart-dev-12-8.
# Preparing to unpack .../033-cuda-cudart-dev-12-8_12.8.57-1_amd64.deb ...
# Unpacking cuda-cudart-dev-12-8 (12.8.57-1) ...
# Selecting previously unselected package cuda-nvvm-12-8.
# Preparing to unpack .../034-cuda-nvvm-12-8_12.8.61-1_amd64.deb ...
# Unpacking cuda-nvvm-12-8 (12.8.61-1) ...
# Selecting previously unselected package cuda-crt-12-8.
# Preparing to unpack .../035-cuda-crt-12-8_12.8.61-1_amd64.deb ...
# Unpacking cuda-crt-12-8 (12.8.61-1) ...
# Selecting previously unselected package cuda-nvcc-12-8.
# Preparing to unpack .../036-cuda-nvcc-12-8_12.8.61-1_amd64.deb ...
# Unpacking cuda-nvcc-12-8 (12.8.61-1) ...
# Selecting previously unselected package cuda-nvprune-12-8.
# Preparing to unpack .../037-cuda-nvprune-12-8_12.8.55-1_amd64.deb ...
# Unpacking cuda-nvprune-12-8 (12.8.55-1) ...
# Selecting previously unselected package cuda-compiler-12-8.
# Preparing to unpack .../038-cuda-compiler-12-8_12.8.0-1_amd64.deb ...
# Unpacking cuda-compiler-12-8 (12.8.0-1) ...
# Selecting previously unselected package cuda-profiler-api-12-8.
# Preparing to unpack .../039-cuda-profiler-api-12-8_12.8.55-1_amd64.deb ...
# Unpacking cuda-profiler-api-12-8 (12.8.55-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-12-8.
# Preparing to unpack .../040-cuda-nvrtc-dev-12-8_12.8.61-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-12-8 (12.8.61-1) ...
# Selecting previously unselected package cuda-opencl-dev-12-8.
# Preparing to unpack .../041-cuda-opencl-dev-12-8_12.8.55-1_amd64.deb ...
# Unpacking cuda-opencl-dev-12-8 (12.8.55-1) ...
# Selecting previously unselected package libcublas-dev-12-8.
# Preparing to unpack .../042-libcublas-dev-12-8_12.8.3.14-1_amd64.deb ...
# Unpacking libcublas-dev-12-8 (12.8.3.14-1) ...
# Selecting previously unselected package libcufft-dev-12-8.
# Preparing to unpack .../043-libcufft-dev-12-8_11.3.3.41-1_amd64.deb ...
# Unpacking libcufft-dev-12-8 (11.3.3.41-1) ...
# Selecting previously unselected package libcufile-dev-12-8.
# Preparing to unpack .../044-libcufile-dev-12-8_1.13.0.11-1_amd64.deb ...
# Unpacking libcufile-dev-12-8 (1.13.0.11-1) ...
# Selecting previously unselected package libcurand-dev-12-8.
# Preparing to unpack .../045-libcurand-dev-12-8_10.3.9.55-1_amd64.deb ...
# Unpacking libcurand-dev-12-8 (10.3.9.55-1) ...
# Selecting previously unselected package libcusolver-dev-12-8.
# Preparing to unpack .../046-libcusolver-dev-12-8_11.7.2.55-1_amd64.deb ...
# Unpacking libcusolver-dev-12-8 (11.7.2.55-1) ...
# Selecting previously unselected package libcusparse-dev-12-8.
# Preparing to unpack .../047-libcusparse-dev-12-8_12.5.7.53-1_amd64.deb ...
# Unpacking libcusparse-dev-12-8 (12.5.7.53-1) ...
# Selecting previously unselected package libnpp-dev-12-8.
# Preparing to unpack .../048-libnpp-dev-12-8_12.3.3.65-1_amd64.deb ...
# Unpacking libnpp-dev-12-8 (12.3.3.65-1) ...
# Selecting previously unselected package libnvjitlink-dev-12-8.
# Preparing to unpack .../049-libnvjitlink-dev-12-8_12.8.61-1_amd64.deb ...
# Unpacking libnvjitlink-dev-12-8 (12.8.61-1) ...
# Selecting previously unselected package libnvfatbin-dev-12-8.
# Preparing to unpack .../050-libnvfatbin-dev-12-8_12.8.55-1_amd64.deb ...
# Unpacking libnvfatbin-dev-12-8 (12.8.55-1) ...
# Selecting previously unselected package libnvjpeg-dev-12-8.
# Preparing to unpack .../051-libnvjpeg-dev-12-8_12.3.5.57-1_amd64.deb ...
# Unpacking libnvjpeg-dev-12-8 (12.3.5.57-1) ...
# Selecting previously unselected package cuda-libraries-dev-12-8.
# Preparing to unpack .../052-cuda-libraries-dev-12-8_12.8.0-1_amd64.deb ...
# Unpacking cuda-libraries-dev-12-8 (12.8.0-1) ...
# Selecting previously unselected package cuda-cupti-12-8.
# Preparing to unpack .../053-cuda-cupti-12-8_12.8.57-1_amd64.deb ...
# Unpacking cuda-cupti-12-8 (12.8.57-1) ...
# Selecting previously unselected package cuda-cupti-dev-12-8.
# Preparing to unpack .../054-cuda-cupti-dev-12-8_12.8.57-1_amd64.deb ...
# Unpacking cuda-cupti-dev-12-8 (12.8.57-1) ...
# Selecting previously unselected package cuda-nvdisasm-12-8.
# Preparing to unpack .../055-cuda-nvdisasm-12-8_12.8.55-1_amd64.deb ...
# Unpacking cuda-nvdisasm-12-8 (12.8.55-1) ...
# Selecting previously unselected package cuda-gdb-12-8.
# Preparing to unpack .../056-cuda-gdb-12-8_12.8.55-1_amd64.deb ...
# Unpacking cuda-gdb-12-8 (12.8.55-1) ...
# Selecting previously unselected package cuda-nvprof-12-8.
# Preparing to unpack .../057-cuda-nvprof-12-8_12.8.57-1_amd64.deb ...
# Unpacking cuda-nvprof-12-8 (12.8.57-1) ...
# Selecting previously unselected package cuda-nvtx-12-8.
# Preparing to unpack .../058-cuda-nvtx-12-8_12.8.55-1_amd64.deb ...
# Unpacking cuda-nvtx-12-8 (12.8.55-1) ...
# Selecting previously unselected package cuda-sanitizer-12-8.
# Preparing to unpack .../059-cuda-sanitizer-12-8_12.8.55-1_amd64.deb ...
# Unpacking cuda-sanitizer-12-8 (12.8.55-1) ...
# Selecting previously unselected package cuda-command-line-tools-12-8.
# Preparing to unpack .../060-cuda-command-line-tools-12-8_12.8.0-1_amd64.deb ...
# Unpacking cuda-command-line-tools-12-8 (12.8.0-1) ...
# Selecting previously unselected package nsight-compute-2025.1.0.
# Preparing to unpack .../061-nsight-compute-2025.1.0_2025.1.0.14-1_amd64.deb ...
# Unpacking nsight-compute-2025.1.0 (2025.1.0.14-1) ...
# Selecting previously unselected package cuda-nsight-compute-12-8.
# Preparing to unpack .../062-cuda-nsight-compute-12-8_12.8.0-1_amd64.deb ...
# Unpacking cuda-nsight-compute-12-8 (12.8.0-1) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../063-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../064-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../065-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../066-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../067-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../068-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../069-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../070-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../071-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-cursor0:amd64.
# Preparing to unpack .../072-libxcb-cursor0_0.1.1-4ubuntu1_amd64.deb ...
# Unpacking libxcb-cursor0:amd64 (0.1.1-4ubuntu1) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../073-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package nsight-systems-2024.6.2.
# Preparing to unpack .../074-nsight-systems-2024.6.2_2024.6.2.225-246235244400v0_amd64.deb ...
# Unpacking nsight-systems-2024.6.2 (2024.6.2.225-246235244400v0) ...
# Selecting previously unselected package cuda-nsight-systems-12-8.
# Preparing to unpack .../075-cuda-nsight-systems-12-8_12.8.0-1_amd64.deb ...
# Unpacking cuda-nsight-systems-12-8 (12.8.0-1) ...
# Selecting previously unselected package default-jre-headless.
# Preparing to unpack .../076-default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../077-openjdk-11-jre_11.0.26+4-1ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.26+4-1ubuntu1~22.04) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../078-default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package cuda-nsight-12-8.
# Preparing to unpack .../079-cuda-nsight-12-8_12.8.55-1_amd64.deb ...
# Unpacking cuda-nsight-12-8 (12.8.55-1) ...
# Selecting previously unselected package cuda-nvml-dev-12-8.
# Preparing to unpack .../080-cuda-nvml-dev-12-8_12.8.55-1_amd64.deb ...
# Unpacking cuda-nvml-dev-12-8 (12.8.55-1) ...
# Selecting previously unselected package cuda-nvvp-12-8.
# Preparing to unpack .../081-cuda-nvvp-12-8_12.8.57-1_amd64.deb ...
# Unpacking cuda-nvvp-12-8 (12.8.57-1) ...
# Selecting previously unselected package cuda-visual-tools-12-8.
# Preparing to unpack .../082-cuda-visual-tools-12-8_12.8.0-1_amd64.deb ...
# Unpacking cuda-visual-tools-12-8 (12.8.0-1) ...
# Selecting previously unselected package gds-tools-12-8.
# Preparing to unpack .../083-gds-tools-12-8_1.13.0.11-1_amd64.deb ...
# Unpacking gds-tools-12-8 (1.13.0.11-1) ...
# Selecting previously unselected package cuda-tools-12-8.
# Preparing to unpack .../084-cuda-tools-12-8_12.8.0-1_amd64.deb ...
# Unpacking cuda-tools-12-8 (12.8.0-1) ...
# Selecting previously unselected package cuda-documentation-12-8.
# Preparing to unpack .../085-cuda-documentation-12-8_12.8.55-1_amd64.deb ...
# Unpacking cuda-documentation-12-8 (12.8.55-1) ...
# Selecting previously unselected package cuda-toolkit-12-8.
# Preparing to unpack .../086-cuda-toolkit-12-8_12.8.0-1_amd64.deb ...
# Unpacking cuda-toolkit-12-8 (12.8.0-1) ...
# Selecting previously unselected package cuda-demo-suite-12-8.
# Preparing to unpack .../087-cuda-demo-suite-12-8_12.8.55-1_amd64.deb ...
# Unpacking cuda-demo-suite-12-8 (12.8.55-1) ...
# Selecting previously unselected package cuda-12-8.
# Preparing to unpack .../088-cuda-12-8_12.8.0-1_amd64.deb ...
# Unpacking cuda-12-8 (12.8.0-1) ...
# Selecting previously unselected package libnvidia-common-570.
# Preparing to unpack .../089-libnvidia-common-570_570.86.15-0ubuntu1_all.deb ...
# Unpacking libnvidia-common-570 (570.86.15-0ubuntu1) ...
# Selecting previously unselected package libnvidia-gl-570:amd64.
# Preparing to unpack .../090-libnvidia-gl-570_570.86.15-0ubuntu1_amd64.deb ...
# dpkg-query: no packages found matching libnvidia-gl-535
# Unpacking libnvidia-gl-570:amd64 (570.86.15-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-source-570-open.
# Preparing to unpack .../091-nvidia-kernel-source-570-open_570.86.15-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-source-570-open (570.86.15-0ubuntu1) ...
# Selecting previously unselected package nvidia-firmware-570-570.86.15.
# Preparing to unpack .../092-nvidia-firmware-570-570.86.15_570.86.15-0ubuntu1_amd64.deb ...
# Unpacking nvidia-firmware-570-570.86.15 (570.86.15-0ubuntu1) ...
# Selecting previously unselected package nvidia-modprobe.
# Preparing to unpack .../093-nvidia-modprobe_570.86.15-0ubuntu1_amd64.deb ...
# Unpacking nvidia-modprobe (570.86.15-0ubuntu1) ...
# Selecting previously unselected package nvidia-kernel-common-570.
# Preparing to unpack .../094-nvidia-kernel-common-570_570.86.15-0ubuntu1_amd64.deb ...
# Unpacking nvidia-kernel-common-570 (570.86.15-0ubuntu1) ...
# Selecting previously unselected package nvidia-dkms-570-open.
# Preparing to unpack .../095-nvidia-dkms-570-open_570.86.15-0ubuntu1_amd64.deb ...
# Unpacking nvidia-dkms-570-open (570.86.15-0ubuntu1) ...
# Selecting previously unselected package libnvidia-extra-570:amd64.
# Preparing to unpack .../096-libnvidia-extra-570_570.86.15-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-extra-570:amd64 (570.86.15-0ubuntu1) ...
# Selecting previously unselected package nvidia-compute-utils-570.
# Preparing to unpack .../097-nvidia-compute-utils-570_570.86.15-0ubuntu1_amd64.deb ...
# Unpacking nvidia-compute-utils-570 (570.86.15-0ubuntu1) ...
# Selecting previously unselected package libnvidia-encode-570:amd64.
# Preparing to unpack .../098-libnvidia-encode-570_570.86.15-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-encode-570:amd64 (570.86.15-0ubuntu1) ...
# Selecting previously unselected package nvidia-utils-570.
# Preparing to unpack .../099-nvidia-utils-570_570.86.15-0ubuntu1_amd64.deb ...
# Unpacking nvidia-utils-570 (570.86.15-0ubuntu1) ...
# Selecting previously unselected package libnvidia-cfg1-570:amd64.
# Preparing to unpack .../100-libnvidia-cfg1-570_570.86.15-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-cfg1-570:amd64 (570.86.15-0ubuntu1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../101-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../102-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../103-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.12_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Selecting previously unselected package libxcvt0:amd64.
# Preparing to unpack .../104-libxcvt0_0.1.1-3_amd64.deb ...
# Unpacking libxcvt0:amd64 (0.1.1-3) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../105-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../106-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package xserver-xorg-core.
# Preparing to unpack .../107-xserver-xorg-core_2%3a21.1.4-2ubuntu1.7~22.04.12_amd64.deb ...
# Unpacking xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Selecting previously unselected package xserver-xorg-video-nvidia-570.
# Preparing to unpack .../108-xserver-xorg-video-nvidia-570_570.86.15-0ubuntu1_amd64.deb ...
# Unpacking xserver-xorg-video-nvidia-570 (570.86.15-0ubuntu1) ...
# Selecting previously unselected package libnvidia-fbc1-570:amd64.
# Preparing to unpack .../109-libnvidia-fbc1-570_570.86.15-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-fbc1-570:amd64 (570.86.15-0ubuntu1) ...
# Selecting previously unselected package nvidia-driver-570-open.
# Preparing to unpack .../110-nvidia-driver-570-open_570.86.15-0ubuntu1_amd64.deb ...
# Unpacking nvidia-driver-570-open (570.86.15-0ubuntu1) ...
# Selecting previously unselected package nvidia-open.
# Preparing to unpack .../111-nvidia-open_570.86.15-0ubuntu1_amd64.deb ...
# Unpacking nvidia-open (570.86.15-0ubuntu1) ...
# Selecting previously unselected package cuda.
# Preparing to unpack .../112-cuda_12.8.0-1_amd64.deb ...
# Unpacking cuda (12.8.0-1) ...
# Selecting previously unselected package libfakeroot:amd64.
# Preparing to unpack .../113-libfakeroot_1.28-1ubuntu1_amd64.deb ...
# Unpacking libfakeroot:amd64 (1.28-1ubuntu1) ...
# Selecting previously unselected package fakeroot.
# Preparing to unpack .../114-fakeroot_1.28-1ubuntu1_amd64.deb ...
# Unpacking fakeroot (1.28-1ubuntu1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../115-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../116-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../117-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../118-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../119-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../120-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../121-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../122-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../123-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../124-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../125-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../126-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../127-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package python3-xkit.
# Preparing to unpack .../128-python3-xkit_0.5.0ubuntu5_all.deb ...
# Unpacking python3-xkit (0.5.0ubuntu5) ...
# Selecting previously unselected package screen-resolution-extra.
# Preparing to unpack .../129-screen-resolution-extra_0.18.2_all.deb ...
# Unpacking screen-resolution-extra (0.18.2) ...
# Selecting previously unselected package nvidia-settings.
# Preparing to unpack .../130-nvidia-settings_570.86.15-0ubuntu1_amd64.deb ...
# Unpacking nvidia-settings (570.86.15-0ubuntu1) ...
# Selecting previously unselected package switcheroo-control.
# Preparing to unpack .../131-switcheroo-control_2.4-3build2_amd64.deb ...
# Unpacking switcheroo-control (2.4-3build2) ...
# Selecting previously unselected package systemd-hwe-hwdb.
# Preparing to unpack .../132-systemd-hwe-hwdb_249.11.5_all.deb ...
# Unpacking systemd-hwe-hwdb (249.11.5) ...
# Selecting previously unselected package xcvt.
# Preparing to unpack .../133-xcvt_0.1.1-3_amd64.deb ...
# Unpacking xcvt (0.1.1-3) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../134-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../135-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../136-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Setting up cuda-nvprof-12-8 (12.8.57-1) ...
# Setting up nsight-compute-2025.1.0 (2025.1.0.14-1) ...
# Setting up nvidia-kernel-source-570-open (570.86.15-0ubuntu1) ...
# Setting up cpp-12 (12.3.0-1ubuntu1~22.04) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up cuda-cuobjdump-12-8 (12.8.55-1) ...
# Setting up cuda-nvrtc-12-8 (12.8.61-1) ...
# Setting up libnvidia-extra-570:amd64 (570.86.15-0ubuntu1) ...
# Setting up cuda-sanitizer-12-8 (12.8.55-1) ...
# Setting up cuda-nvvm-12-8 (12.8.61-1) ...
# Setting up cuda-nvprune-12-8 (12.8.55-1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up cuda-cupti-12-8 (12.8.57-1) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up cuda-nvml-dev-12-8 (12.8.55-1) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up openjdk-11-jre:amd64 (11.0.26+4-1ubuntu1~22.04) ...
# Setting up cuda-toolkit-12-8-config-common (12.8.57-1) ...
# Setting alternatives
# update-alternatives: using /usr/local/cuda-12.8 to provide /usr/local/cuda (cuda) in auto mode
# update-alternatives: using /usr/local/cuda-12.8 to provide /usr/local/cuda-12 (cuda-12) in auto mode
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up cuda-nvrtc-dev-12-8 (12.8.61-1) ...
# Setting up libfakeroot:amd64 (1.28-1ubuntu1) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libjansson4:amd64 (2.13.1-1.1build3) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up nvidia-modprobe (570.86.15-0ubuntu1) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up fakeroot (1.28-1ubuntu1) ...
# update-alternatives: using /usr/bin/fakeroot-sysv to provide /usr/bin/fakeroot (fakeroot) in auto mode
# Setting up cuda-driver-dev-12-8 (12.8.57-1) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up libnvidia-common-570 (570.86.15-0ubuntu1) ...
# Setting up cuda-documentation-12-8 (12.8.55-1) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up cuda-nvvp-12-8 (12.8.57-1) ...
# Setting up nvidia-firmware-570-570.86.15 (570.86.15-0ubuntu1) ...
# Setting up libxcb-cursor0:amd64 (0.1.1-4ubuntu1) ...
# Setting up cuda-profiler-api-12-8 (12.8.55-1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libnvidia-cfg1-570:amd64 (570.86.15-0ubuntu1) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up libcusolver-12-8 (11.7.2.55-1) ...
# Setting up udev (249.11-0ubuntu3.12) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up cuda-demo-suite-12-8 (12.8.55-1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up cuda-nvdisasm-12-8 (12.8.55-1) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libnvfatbin-12-8 (12.8.55-1) ...
# Setting up libnvjpeg-12-8 (12.3.5.57-1) ...
# Setting up systemd-hwe-hwdb (249.11.5) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up libcusolver-dev-12-8 (11.7.2.55-1) ...
# Setting up cuda-nsight-compute-12-8 (12.8.0-1) ...
# Setting up libcufile-12-8 (1.13.0.11-1) ...
# Setting alternatives
# update-alternatives: using /usr/local/cuda-12.8/gds/cufile.json to provide /etc/cufile.json (cufile.json) in auto mode
# Setting up libasan8:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up libxcvt0:amd64 (0.1.1-3) ...
# Setting up cuda-cuxxfilt-12-8 (12.8.55-1) ...
# Setting up cuda-nvtx-12-8 (12.8.55-1) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libnvfatbin-dev-12-8 (12.8.55-1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libtsan2:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up cuda-cccl-12-8 (12.8.55-1) ...
# Setting up python3-xkit (0.5.0ubuntu5) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up cuda-cudart-12-8 (12.8.57-1) ...
# Setting up cuda-cupti-dev-12-8 (12.8.57-1) ...
# Setting up liblocale-gettext-perl (1.07-4build3) ...
# Setting up libnvidia-fbc1-570:amd64 (570.86.15-0ubuntu1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up dctrl-tools (2.24-3build2) ...
# Setting up cuda-nsight-12-8 (12.8.55-1) ...
# Setting up cuda-cudart-dev-12-8 (12.8.57-1) ...
# Setting up gds-tools-12-8 (1.13.0.11-1) ...
# Setting up nvidia-kernel-common-570 (570.86.15-0ubuntu1) ...
# Setting up cuda-crt-12-8 (12.8.61-1) ...
# Setting up libcufft-12-8 (11.3.3.41-1) ...
# Setting up libcublas-12-8 (12.8.3.14-1) ...
# Setting up libcusparse-12-8 (12.5.7.53-1) ...
# Setting up libnvjpeg-dev-12-8 (12.3.5.57-1) ...
# Setting up libnvidia-gl-570:amd64 (570.86.15-0ubuntu1) ...
# Setting up libnvjitlink-12-8 (12.8.61-1) ...
# Setting up libcufile-dev-12-8 (1.13.0.11-1) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up libcurand-12-8 (10.3.9.55-1) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libcufft-dev-12-8 (11.3.3.41-1) ...
# Setting up libnpp-12-8 (12.3.3.65-1) ...
# Setting up libnpp-dev-12-8 (12.3.3.65-1) ...
# Setting up cuda-opencl-12-8 (12.8.55-1) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up xcvt (0.1.1-3) ...
# Setting up cuda-gdb-12-8 (12.8.55-1) ...
# Setting up nsight-systems-2024.6.2 (2024.6.2.225-246235244400v0) ...
# update-alternatives: using /opt/nvidia/nsight-systems/2024.6.2/target-linux-x64/nsys to provide /usr/local/bin/nsys (nsys) in auto mode
# update-alternatives: using /opt/nvidia/nsight-systems/2024.6.2/host-linux-x64/nsys-ui to provide /usr/local/bin/nsys-ui (nsys-ui) in auto mode
# Setting up xfonts-base (1:1.0.5) ...
# Setting up libnvjitlink-dev-12-8 (12.8.61-1) ...
# Setting up libgcc-12-dev:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up cuda-libraries-12-8 (12.8.0-1) ...
# Setting up cuda-nsight-systems-12-8 (12.8.0-1) ...
# Setting up screen-resolution-extra (0.18.2) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libcurand-dev-12-8 (10.3.9.55-1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up switcheroo-control (2.4-3build2) ...
# Created symlink /etc/systemd/system/graphical.target.wants/switcheroo-control.service → /lib/systemd/system/switcheroo-control.service.
# Setting up x11-utils (7.7+5build2) ...
# Setting up nvidia-settings (570.86.15-0ubuntu1) ...
# Setting up libcusparse-dev-12-8 (12.5.7.53-1) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up keyboard-configuration (1.205ubuntu3) ...
# Your console font configuration will be updated the next time your system
# boots. If you want to update it now, run 'setupcon' from a virtual console.
# Setting up libcublas-dev-12-8 (12.8.3.14-1) ...
# Setting up cuda-nvcc-12-8 (12.8.61-1) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up cuda-opencl-dev-12-8 (12.8.55-1) ...
# Setting up xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.12) ...
# Setting up cuda-command-line-tools-12-8 (12.8.0-1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up gcc-12 (12.3.0-1ubuntu1~22.04) ...
# Setting up cuda-compiler-12-8 (12.8.0-1) ...
# Setting up cuda-libraries-dev-12-8 (12.8.0-1) ...
# Setting up cuda-visual-tools-12-8 (12.8.0-1) ...
# Setting up cuda-tools-12-8 (12.8.0-1) ...
# Setting up cuda-toolkit-12-8 (12.8.0-1) ...
# Setting up xserver-xorg-video-nvidia-570 (570.86.15-0ubuntu1) ...
# Setting up dkms (2.8.7-2ubuntu2.2) ...
# Setting up nvidia-dkms-570-open (570.86.15-0ubuntu1) ...
# Loading new nvidia-570.86.15 DKMS files...
# It is likely that 6.1.85+ belongs to a chroot's host
# Building for 5.15.0-131-generic
# Building for architecture x86_64
# Building initial module for 5.15.0-131-generic
# Done.
#
# nvidia.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-131-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-131-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-131-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-131-generic/updates/dkms/
#
# nvidia-peermem.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/5.15.0-131-generic/updates/dkms/
#
# depmod...
# Setting up libnvidia-decode-570:amd64 (570.86.15-0ubuntu1) ...
# Setting up libnvidia-compute-570:amd64 (570.86.15-0ubuntu1) ...
# Setting up libnvidia-encode-570:amd64 (570.86.15-0ubuntu1) ...
# Setting up nvidia-utils-570 (570.86.15-0ubuntu1) ...
# Setting up nvidia-compute-utils-570 (570.86.15-0ubuntu1) ...
# Setting up cuda-runtime-12-8 (12.8.0-1) ...
# Setting up nvidia-driver-570-open (570.86.15-0ubuntu1) ...
# Setting up cuda-12-8 (12.8.0-1) ...
# Setting up nvidia-open (570.86.15-0ubuntu1) ...
# Setting up cuda (12.8.0-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...

# %%
# %%writefile diffusion_mpi_hybrid.cu
# #include <stdio.h>
# #include <stdlib.h>
# #include <math.h>
# #include <cuda_runtime.h>
# #include <mpi.h>
# #include <omp.h>
#
# #define N 600  // Tamanho da grade
# #define T 1000   // Número de passos de tempo
# #define D 0.1   // Coeficiente de difusão
# #define DELTA_T 0.01
# #define DELTA_X 1.0
# #define TAMANHO_BLOCO 32  // Aumentado de 16 para 32 para melhor aproveitamento da GPU
# #define INTERVALO_IMPRESSAO 100
#
# // Macro para verificar erros CUDA
# #define VERIFICAR_ERRO_CUDA(chamada) { \
#     cudaError_t erro = chamada; \
#     if (erro != cudaSuccess) { \
#         fprintf(stderr, "Erro CUDA em %s:%d: %s\n", __FILE__, __LINE__, \
#                 cudaGetErrorString(erro)); \
#         exit(EXIT_FAILURE); \
#     } \
# }
#
# __global__ void kernel_equacao_difusao(double *C, double *C_novo, int linhas, int colunas) {
#     __shared__ double bloco_compartilhado[TAMANHO_BLOCO + 2][TAMANHO_BLOCO + 2];
#
#     int i = blockIdx.y * blockDim.y + threadIdx.y;
#     int j = blockIdx.x * blockDim.x + threadIdx.x;
#     int tx = threadIdx.x + 1;
#     int ty = threadIdx.y + 1;
#
#     // Carregar dados na memória compartilhada
#     if (i < linhas && j < colunas) {
#         bloco_compartilhado[ty][tx] = C[i * colunas + j];
#
#         // Carregar as regiões de halo
#         if (threadIdx.x == 0 && j > 0)
#             bloco_compartilhado[ty][0] = C[i * colunas + (j-1)];
#         if (threadIdx.x == TAMANHO_BLOCO-1 && j < colunas-1)
#             bloco_compartilhado[ty][tx+1] = C[i * colunas + (j+1)];
#         if (threadIdx.y == 0 && i > 0)
#             bloco_compartilhado[0][tx] = C[(i-1) * colunas + j];
#         if (threadIdx.y == TAMANHO_BLOCO-1 && i < linhas-1)
#             bloco_compartilhado[ty+1][tx] = C[(i+1) * colunas + j];
#     }
#
#     __syncthreads();
#
#     if (i > 0 && i < linhas-1 && j > 0 && j < colunas-1) {
#         double laplaciano = (bloco_compartilhado[ty-1][tx] + bloco_compartilhado[ty+1][tx] +
#                              bloco_compartilhado[ty][tx-1] + bloco_compartilhado[ty][tx+1] -
#                              4.0 * bloco_compartilhado[ty][tx]) / (DELTA_X * DELTA_X);
#         C_novo[i * colunas + j] = bloco_compartilhado[ty][tx] + D * DELTA_T * laplaciano;
#     } else if (i < linhas && j < colunas) {
#         C_novo[i * colunas + j] = C[i * colunas + j];  // Preservar os valores de fronteira
#     }
# }
#
# void imprimir_estatisticas_regiao(double *local_C, int linhas_local, int colunas_local, int rank, int t) {
#     double min_val = local_C[0];
#     double max_val = local_C[0];
#     double soma = 0.0;
#
#     #pragma omp parallel for collapse(2) reduction(min:min_val) reduction(max:max_val) reduction(+:soma)
#     for (int i = 0; i < linhas_local; i++) {
#         for (int j = 0; j < colunas_local; j++) {
#             double val = local_C[i * colunas_local + j];
#             min_val = fmin(min_val, val);
#             max_val = fmax(max_val, val);
#             soma += val;
#         }
#     }
#     double media_val = soma / (linhas_local * colunas_local);
#
#     printf("Passo %d [Rank %d] - Estatísticas da Região:\n", t, rank);
#     printf("  * Valor Mínimo: %.4f\n", min_val);
#     printf("  * Valor Máximo: %.4f\n", max_val);
#     printf("  * Média: %.4f\n", media_val);
#     printf("------------------------------------------------\n");
# }
#
# void difusao_mpi_hibrida(double *local_C, double *local_C_novo, int linhas_local, int colunas_local,
#                         int linhas_totais, int colunas_totais, int rank, int num_procs, double *tempo) {
#     double tempo_inicial = MPI_Wtime();
#     double tempo_computacao = 0.0;
#     double tempo_comunicacao = 0.0;
#     int trocas_fronteira = 0;
#
#     // Alocar memória na GPU e criar streams
#     double *d_local_C, *d_local_C_novo;
#     size_t tamanho_local = linhas_local * colunas_local * sizeof(double);
#     cudaStream_t stream_computacao, stream_comunicacao;
#
#     VERIFICAR_ERRO_CUDA(cudaMalloc((void**)&d_local_C, tamanho_local));
#     VERIFICAR_ERRO_CUDA(cudaMalloc((void**)&d_local_C_novo, tamanho_local));
#     VERIFICAR_ERRO_CUDA(cudaStreamCreate(&stream_computacao));
#     VERIFICAR_ERRO_CUDA(cudaStreamCreate(&stream_comunicacao));
#
#     // Transferir dados iniciais para a GPU
#     VERIFICAR_ERRO_CUDA(cudaMemcpyAsync(d_local_C, local_C, tamanho_local,
#                                        cudaMemcpyHostToDevice, stream_computacao));
#
#     dim3 dim_bloqueio(TAMANHO_BLOCO, TAMANHO_BLOCO);
#     dim3 dim_grade((colunas_local + TAMANHO_BLOCO - 1) / TAMANHO_BLOCO,
#                    (linhas_local + TAMANHO_BLOCO - 1) / TAMANHO_BLOCO);
#
#     // Alocar buffers para comunicação não bloqueante
#     double *enviar_topo = NULL, *enviar_fundo = NULL;
#     double *receber_topo = NULL, *receber_fundo = NULL;
#     if (rank > 0) {
#         enviar_topo = (double*)malloc(colunas_local * sizeof(double));
#         receber_topo = (double*)malloc(colunas_local * sizeof(double));
#     }
#     if (rank < num_procs - 1) {
#         enviar_fundo = (double*)malloc(colunas_local * sizeof(double));
#         receber_fundo = (double*)malloc(colunas_local * sizeof(double));
#     }
#
#     for (int t = 0; t < T; t++) {
#         double inicio_troca = MPI_Wtime();
#         MPI_Request requisicoes[4];
#         int contagem_reqs = 0;
#
#         // Copiar dados de fronteira para comunicação
#         if (rank > 0) {
#             VERIFICAR_ERRO_CUDA(cudaMemcpyAsync(enviar_topo, d_local_C + colunas_local,
#                                                colunas_local * sizeof(double),
#                                                cudaMemcpyDeviceToHost, stream_comunicacao));
#         }
#         if (rank < num_procs - 1) {
#             VERIFICAR_ERRO_CUDA(cudaMemcpyAsync(enviar_fundo,
#                                                d_local_C + (linhas_local-2)*colunas_local,
#                                                colunas_local * sizeof(double),
#                                                cudaMemcpyDeviceToHost, stream_comunicacao));
#         }
#         VERIFICAR_ERRO_CUDA(cudaStreamSynchronize(stream_comunicacao));
#
#         // Comunicação não bloqueante
#         if (rank > 0) {
#             MPI_Isend(enviar_topo, colunas_local, MPI_DOUBLE, rank-1, 0,
#                      MPI_COMM_WORLD, &requisicoes[contagem_reqs++]);
#             MPI_Irecv(receber_topo, colunas_local, MPI_DOUBLE, rank-1, 0,
#                      MPI_COMM_WORLD, &requisicoes[contagem_reqs++]);
#             trocas_fronteira++;
#         }
#         if (rank < num_procs - 1) {
#             MPI_Isend(enviar_fundo, colunas_local, MPI_DOUBLE, rank+1, 0,
#                      MPI_COMM_WORLD, &requisicoes[contagem_reqs++]);
#             MPI_Irecv(receber_fundo, colunas_local, MPI_DOUBLE, rank+1, 0,
#                      MPI_COMM_WORLD, &requisicoes[contagem_reqs++]);
#             trocas_fronteira++;
#         }
#
#         // Cálculos internos enquanto a comunicação ocorre
#         double inicio_computacao = MPI_Wtime();
#         kernel_equacao_difusao<<<dim_grade, dim_bloqueio, 0, stream_computacao>>>(d_local_C, d_local_C_novo,
#                                                                                linhas_local, colunas_local);
#
#         // Aguardar a comunicação ser concluída
#         MPI_Waitall(contagem_reqs, requisicoes, MPI_STATUSES_IGNORE);
#         tempo_comunicacao += MPI_Wtime() - inicio_troca;
#
#         // Atualizar fronteiras na GPU
#         if (rank > 0) {
#             VERIFICAR_ERRO_CUDA(cudaMemcpyAsync(d_local_C, receber_topo,
#                                                colunas_local * sizeof(double),
#                                                cudaMemcpyHostToDevice, stream_comunicacao));
#         }
#         if (rank < num_procs - 1) {
#             VERIFICAR_ERRO_CUDA(cudaMemcpyAsync(d_local_C + (linhas_local-1)*colunas_local,
#                                                receber_fundo, colunas_local * sizeof(double),
#                                                cudaMemcpyHostToDevice, stream_comunicacao));
#         }
#
#         VERIFICAR_ERRO_CUDA(cudaStreamSynchronize(stream_computacao));
#         VERIFICAR_ERRO_CUDA(cudaStreamSynchronize(stream_comunicacao));
#         tempo_computacao += MPI_Wtime() - inicio_computacao;
#
#         // Trocar ponteiros
#         double *temp = d_local_C;
#         d_local_C = d_local_C_novo;
#         d_local_C_novo = temp;
#
#         if (t % INTERVALO_IMPRESSAO == 0) {
#             VERIFICAR_ERRO_CUDA(cudaMemcpy(local_C, d_local_C, tamanho_local,
#                                           cudaMemcpyDeviceToHost));
#             imprimir_estatisticas_regiao(local_C, linhas_local, colunas_local, rank, t);
#         }
#     }
#
#     // Limpeza
#     VERIFICAR_ERRO_CUDA(cudaMemcpy(local_C, d_local_C, tamanho_local, cudaMemcpyDeviceToHost));
#     VERIFICAR_ERRO_CUDA(cudaFree(d_local_C));
#     VERIFICAR_ERRO_CUDA(cudaFree(d_local_C_novo));
#     VERIFICAR_ERRO_CUDA(cudaStreamDestroy(stream_computacao));
#     VERIFICAR_ERRO_CUDA(cudaStreamDestroy(stream_comunicacao));
#
#     if (enviar_topo) free(enviar_topo);
#     if (enviar_fundo) free(enviar_fundo);
#     if (receber_topo) free(receber_topo);
#     if (receber_fundo) free(receber_fundo);
#
#     double tempo_final = MPI_Wtime();
#     *tempo = (tempo_final - tempo_inicial) * 1000;
#
#     printf("\nMétricas de Desempenho - Processo %d:\n", rank);
#     printf("  * Tempo Total (ms): %.4f\n", *tempo);
#     printf("  * Tempo de Computação (ms): %.4f\n", tempo_computacao * 1000);
#     printf("  * Tempo de Comunicação (ms): %.4f\n", tempo_comunicacao * 1000);
#     printf("  * Trocas de Fronteira: %d\n", trocas_fronteira);
# }
#
# int main(int argc, char** argv) {
#     int rank, num_procs;
#     MPI_Init(&argc, &argv);
#     MPI_Comm_rank(MPI_COMM_WORLD, &rank);
#     MPI_Comm_size(MPI_COMM_WORLD, &num_procs);
#
#     int linhas_local = N / num_procs;
#     int colunas_local = N;
#
#     double *local_C = (double*)malloc(linhas_local * colunas_local * sizeof(double));
#     double *local_C_novo = (double*)malloc(linhas_local * colunas_local * sizeof(double));
#
#     // Inicialização da matriz
#     for (int i = 0; i < linhas_local; i++) {
#         for (int j = 0; j < colunas_local; j++) {
#             local_C[i * colunas_local + j] = 100.0; // Valor inicial para a difusão
#         }
#     }
#
#     double tempo;
#     difusao_mpi_hibrida(local_C, local_C_novo, linhas_local, colunas_local, N, N, rank, num_procs, &tempo);
#
#     free(local_C);
#     free(local_C_novo);
#
#     MPI_Finalize();
#     return 0;
# }
# Out:
# Writing diffusion_mpi_hybrid.cu

# %%
# !apt-get update
# !apt-get install -y openmpi-bin openmpi-common libopenmpi-dev
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libopenmpi-dev is already the newest version (4.1.2-2ubuntu1).
# openmpi-bin is already the newest version (4.1.2-2ubuntu1).
# openmpi-bin set to manually installed.
# openmpi-common is already the newest version (4.1.2-2ubuntu1).
# openmpi-common set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.

# %%
# !mpicc --version
# Out:
# gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !find / -name mpi.h 2>/dev/null
# Out:
# /usr/src/linux-headers-5.15.0-131/include/linux/mpi.h
# /usr/lib/x86_64-linux-gnu/fortran/gfortran-mod-15/openmpi/mpi.h
# /usr/lib/x86_64-linux-gnu/openmpi/include/mpi.h
# /usr/include/x86_64-linux-gnu/mpich/mpi.h
# /usr/include/mumps_seq/mpi.h

# %%
# !nvcc -o diffusion_mpi_hybrid diffusion_mpi_hybrid.cu -I/usr/lib/x86_64-linux-gnu/openmpi/include -L/usr/lib/x86_64-linux-gnu/openmpi/lib -lmpi -lcuda
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !mpirun --allow-run-as-root -hostfile hostfile.txt -np 1 ./diffusion_mpi_hybrid
# Out:
# Passo 0 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 100 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 200 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 300 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 400 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 500 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 600 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 700 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 800 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 900 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#
# Métricas de Desempenho - Processo 0:
#   * Tempo Total (ms): 267.0948
#   * Tempo de Computação (ms): 49.1538
#   * Tempo de Comunicação (ms): 48.6899
#   * Trocas de Fronteira: 0

# %%
# !mpirun --allow-run-as-root -hostfile hostfile.txt -np 2 ./diffusion_mpi_hybrid
# Out:
# Passo 0 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 0 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 100 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 100 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 200 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 200 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 300 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 300 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 400 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 400 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 500 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 500 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 600 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 600 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 700 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 700 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 800 [Rank 0] - Estatísticas da Região:
# Passo 800 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 900 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 900 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#
# Métricas de Desempenho - Processo 0:
#   * Tempo Total (ms): 561.6199
#   * Tempo de Computação (ms): 352.5996
#   * Tempo de Comunicação (ms): 196.9999
#   * Trocas de Fronteira: 1000
#
# Métricas de Desempenho - Processo 1:
#   * Tempo Total (ms): 561.6876
#   * Tempo de Computação (ms): 355.7124
#   * Tempo de Comunicação (ms): 239.4703
#   * Trocas de Fronteira: 1000

# %%
# !mpirun --allow-run-as-root -hostfile hostfile.txt -np 4 ./diffusion_mpi_hybrid
# Out:
# Passo 0 [Rank 2] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 0 [Rank 1] - Estatísticas da Região:
# Passo 0 [Rank 3] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 0 [Rank 0] - Estatísticas da Região:
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 100 [Rank 3] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 100 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 100 [Rank 2] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 100 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 200 [Rank 3] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 200 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 200 [Rank 2] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 200 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 300 [Rank 3] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 300 [Rank 2] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 300 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 300 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 400 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
# Passo 400 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 400 [Rank 3] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 400 [Rank 2] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 500 [Rank 3] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 500 [Rank 2] - Estatísticas da Região:
# Passo 500 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 500 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 600 [Rank 3] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 600 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 600 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 600 [Rank 2] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 700 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 700 [Rank 3] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 700 [Rank 2] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 700 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 800 [Rank 3] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 800 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 800 [Rank 2] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 800 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 900 [Rank 3] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 900 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 900 [Rank 2] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 900 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#
# Métricas de Desempenho - Processo 3:
#   * Tempo Total (ms): 12002.2317
#   * Tempo de Computação (ms): 11656.3099
#   * Tempo de Comunicação (ms): 11474.4585
#   * Trocas de Fronteira: 1000
#
# Métricas de Desempenho - Processo 0:
#   * Tempo Total (ms): 12016.4120
#   * Tempo de Computação (ms): 11626.6129
#   * Tempo de Comunicação (ms): 11477.2560
#   * Trocas de Fronteira: 1000
#
# Métricas de Desempenho - Processo 2:
#   * Tempo Total (ms): 12017.2393
#   * Tempo de Computação (ms): 11610.5598
#   * Tempo de Comunicação (ms): 11451.4995
#   * Trocas de Fronteira: 2000
#
# Métricas de Desempenho - Processo 1:
#   * Tempo Total (ms): 12013.1306
#   * Tempo de Computação (ms): 11677.3676
#   * Tempo de Comunicação (ms): 11528.0992
#   * Trocas de Fronteira: 2000

# %%
# !mpirun --allow-run-as-root -hostfile hostfile.txt -np 8 ./diffusion_mpi_hybrid
# Out:
# Passo 0 [Rank 3] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 0 [Rank 7] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 0 [Rank 2] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 0 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 0 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 0 [Rank 6] - Estatísticas da Região:
# Passo 0 [Rank 4] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 0 [Rank 5] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 100 [Rank 5] - Estatísticas da Região:
# Passo 100 [Rank 7] - Estatísticas da Região:
# Passo 100 [Rank 3] - Estatísticas da Região:
# Passo 100 [Rank 4] - Estatísticas da Região:
# Passo 100 [Rank 0] - Estatísticas da Região:
# Passo 100 [Rank 6] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 100 [Rank 2] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 100 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 200 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 200 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 200 [Rank 2] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 200 [Rank 7] - Estatísticas da Região:
# Passo 200 [Rank 3] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 200 [Rank 6] - Estatísticas da Região:
# Passo 200 [Rank 4] - Estatísticas da Região:
# Passo 200 [Rank 5] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 300 [Rank 7] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 300 [Rank 6] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 300 [Rank 0] - Estatísticas da Região:
# Passo 300 [Rank 5] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 300 [Rank 4] - Estatísticas da Região:
# Passo 300 [Rank 3] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 300 [Rank 1] - Estatísticas da Região:
# Passo 300 [Rank 2] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 400 [Rank 7] - Estatísticas da Região:
# Passo 400 [Rank 4] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 400 [Rank 6] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 400 [Rank 5] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 400 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 400 [Rank 3] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
# Passo 400 [Rank 2] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 400 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 500 [Rank 7] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 500 [Rank 2] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 500 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 500 [Rank 5] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 500 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 500 [Rank 4] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 500 [Rank 3] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 500 [Rank 6] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 600 [Rank 7] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 600 [Rank 6] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 600 [Rank 5] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 600 [Rank 4] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
# Passo 600 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 600 [Rank 3] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 600 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 600 [Rank 2] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 700 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 700 [Rank 3] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
# Passo 700 [Rank 2] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
# Passo 700 [Rank 5] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 700 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 700 [Rank 4] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 700 [Rank 7] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 700 [Rank 6] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 800 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 800 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
# Passo 800 [Rank 2] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 800 [Rank 7] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 800 [Rank 3] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 800 [Rank 6] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 800 [Rank 4] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 800 [Rank 5] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 900 [Rank 0] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 900 [Rank 1] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 900 [Rank 2] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 900 [Rank 7] - Estatísticas da Região:
# Passo 900 [Rank 3] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 900 [Rank 6] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
# Passo 900 [Rank 5] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
# Passo 900 [Rank 4] - Estatísticas da Região:
#   * Valor Mínimo: 0.0000
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#   * Valor Máximo: 0.0000
#   * Média: 0.0000
# ------------------------------------------------
#
# Métricas de Desempenho - Processo 7:
#   * Tempo Total (ms): 17750.4138
#   * Tempo de Computação (ms): 17001.0097
#   * Tempo de Comunicação (ms): 16814.3885
#   * Trocas de Fronteira: 1000
#
# Métricas de Desempenho - Processo 6:
#   * Tempo Total (ms): 17772.9836
#   * Tempo de Computação (ms): 16935.2225
#   * Tempo de Comunicação (ms): 16795.3531
#   * Trocas de Fronteira: 2000
#
# Métricas de Desempenho - Processo 5:
#   * Tempo Total (ms): 17779.6895
#   * Tempo de Computação (ms): 16928.4065
#   * Tempo de Comunicação (ms): 16740.2256
#   * Trocas de Fronteira: 2000
#
# Métricas de Desempenho - Processo 4:
#   * Tempo Total (ms): 17761.2378
#   * Tempo de Computação (ms): 17077.6667
#   * Tempo de Comunicação (ms): 16869.9584
#   * Trocas de Fronteira: 2000
#
# Métricas de Desempenho - Processo 2:
#   * Tempo Total (ms): 17777.8094
#   * Tempo de Computação (ms): 17016.0893
#   * Tempo de Comunicação (ms): 16839.7349
#   * Trocas de Fronteira: 2000
#
#
# Métricas de Desempenho - Processo 0:
#   * Tempo Total (ms): 17777.3613
#   * Tempo de Computação (ms): 16964.8700
#   * Tempo de Comunicação (ms): 16780.9519
#   * Trocas de Fronteira: 1000
# Métricas de Desempenho - Processo 1:
#   * Tempo Total (ms): 17785.7122
#   * Tempo de Computação (ms): 16966.3294
#   * Tempo de Comunicação (ms): 16810.9844
#   * Trocas de Fronteira: 2000
#
# Métricas de Desempenho - Processo 3:
#   * Tempo Total (ms): 17785.5194
#   * Tempo de Computação (ms): 17068.6236
#   * Tempo de Comunicação (ms): 16882.2181
#   * Trocas de Fronteira: 2000

# %%
import numpy as np
import matplotlib.pyplot as plt

# Dados para comparação de tempo de execução
implementacoes = ['OpenMP', 'CUDA', 'MPI']
tempos_execucao = [5.84, 1.87, 0.2670948]  # Tempos Sequenciais

# Dados de speedup para diferentes implementações
n_threads_openmp = [1, 2, 4, 8, 16, 32]
speedup_openmp = [1, 1.12, 1.10, 0.94, 1.02, 0.96]

n_threads_cuda = [1, 2, 4, 8, 16, 32]
speedup_cuda = [1, 1.76, 1.34, 2.42, 1.35, 1.43]

n_processos_mpi = [1, 2, 4, 8]
speedup_mpi = [1, 0.4755, 0.0222, 0.0150]

# Dados de eficiência para diferentes implementações
eficiencia_openmp = [100, 55.83, 13.77, 11.87, 6.40, 2.97]
eficiencia_cuda = [100, 88.2, 33.63, 30.35, 8.47, 4.49]
eficiencia_mpi = [100, 23.78, 0.55, 0.19]

# Criando a figura com 2 subgráficos
fig, axs = plt.subplots(1, 2, figsize=(16, 6))

# Subgráfico 1: Comparação do tempo de execução
axs[0].bar(implementacoes, tempos_execucao, color=['skyblue', 'lightgreen', 'lightcoral'])
axs[0].set_xlabel('Implementação')
axs[0].set_ylabel('Tempo de Execução (s)')
axs[0].set_title('Tempo de Execução Sequencial')
axs[0].grid(axis='y')  # Grid apenas no eixo y

# Subgráfico 2: Comparação da eficiência
axs[1].plot(n_threads_openmp, eficiencia_openmp, marker='o', linestyle='-', color='skyblue', label='OpenMP')
axs[1].plot(n_threads_cuda, eficiencia_cuda, marker='o', linestyle='-', color='lightgreen', label='CUDA')
axs[1].plot(n_processos_mpi, eficiencia_mpi, marker='o', linestyle='-', color='lightcoral', label='MPI')
axs[1].set_xlabel('Número de Threads/Processos')
axs[1].set_ylabel('Eficiência (%)')
axs[1].set_title('Eficiência das Implementações Paralelas')
axs[1].set_xticks(np.concatenate((n_threads_openmp, n_threads_cuda, n_processos_mpi)))
axs[1].legend()
axs[1].grid(True)

# Ajustar layout e exibir
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Número de threads/processos usados
threads = np.array([1, 2, 4, 8, 16, 32])

# Speedup fornecido para cada implementação
speedup_mpi = np.array([1, 0.4755, 0.0222, 0.0150, np.nan, np.nan])  # MPI até 8 threads
speedup_omp = np.array([1, 1.12, 1.10, 0.94, 1.02, 0.96])  # OpenMP até 32 threads
speedup_cuda = np.array([1, 1.76, 1.34, 2.42, 1.35, 1.43])  # CUDA até 32 threads

# Speedup ideal (linha de referência para comparação)
speedup_linear = threads

# Criando o gráfico
plt.figure(figsize=(8, 6))

# Plotando os dados
plt.plot(threads, speedup_mpi, 'x-', label="MPI Speedup", markersize=8, color='blue', alpha=0.7)
plt.plot(threads, speedup_omp, 'o-', label="OpenMP Speedup", markersize=8, color='orange', alpha=0.7)
plt.plot(threads, speedup_cuda, 's-', label="CUDA Speedup", markersize=8, color='red', alpha=0.7)
plt.plot(threads, speedup_linear, 'g--', label="Speedup Linear Ideal")

# Configurações do gráfico
plt.xlabel("Número de Threads / Processos")
plt.ylabel("Speedup")
plt.title("Comparação de Speedup: MPI vs OpenMP vs CUDA")
plt.legend()
plt.grid(True)
plt.xticks(threads)

# Exibir gráfico
plt.show()
